# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\notan\\Desktop\\CodeVault\\Data Science Projects\\Amazon Sentiment Analyzer\\venv\\Scripts\\python.exe'

# %%
import pandas
import sklearn
import nltk
print("All good 🎉")
# Out:
# All good 🎉
